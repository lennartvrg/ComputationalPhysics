# %%
# Standard imports for computation physics
import matplotlib.pyplot as plt
import pandas as pd
import scienceplots

# Pretty styling for graphs
plt.style.use(['science', 'notebook'])
plt.rcParams["figure.figsize"] = (12, 8)

# %%
for s in [2, 4, 6]:
    data = pd.read_csv(f'output/sequence{s}.csv', header=None, names=['Value'])
    plt.hist(data['Value'], bins=20)
    plt.show()

# %%
for lam in [0.0, 0.5, 1.0, 2.0]:
    data = pd.read_csv(f'output/sequence_biased{lam:.1f}.csv', header=None, names=['Value'])
    plt.hist(data['Value'], bins=20)
    plt.show()
